# %%
import numpy as np
import matplotlib.pyplot as plt
#from pydgrid.plot_bokeh import plot_results
import sympy as sym
import pydae.build as db
import pydae.build_cffi as db

from pydae.grid_urisi import unb_ri_si
import json

# %%
# !pip install pydgrid
# Out:
# Collecting pydgrid
#   Downloading pydgrid-0.5.3-py2.py3-none-any.whl.metadata (270 bytes)
# Downloading pydgrid-0.5.3-py2.py3-none-any.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.2 MB 393.8 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/4.2 MB 1.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.5/4.2 MB 2.9 MB/s eta 0:00:02
#    -------- ------------------------------- 0.9/4.2 MB 3.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/4.2 MB 4.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.2/4.2 MB 3.8 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.2 MB 3.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.2 MB 4.2 MB/s eta 0:00:01
#    ------------------- -------------------- 2.0/4.2 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.2 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.2 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.2 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.2 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.2 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.2 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.2 MB 2.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.3/4.2 MB 2.7 MB/s eta 0:00:01
#    -------------------------- ------------- 2.7/4.2 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.0/4.2 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 3.4/4.2 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  4.1/4.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: pydgrid
# Successfully installed pydgrid-0.5.3

# %%
grid = unb_ri_si('cigre_eu_lv_com.json')

params_dict  = grid.dae['params']
f_list = grid.dae['f']
x_list = grid.dae['x']
g_list = grid.dae['g'] 
y_list = grid.dae['y'] 
u_dict = grid.dae['u']


h_dict = grid.dae['h_dict']
h_dict.update(grid.dae['h_v_m_dict'])

sys_dict = {'name':'cigre_eu_lv_com',
           'params_dict':params_dict,
           'f_list':f_list,
           'g_list':g_list,
           'x_list':x_list,
           'y_ini_list':y_list,
           'y_run_list':y_list,
           'u_run_dict':u_dict,
           'u_ini_dict':u_dict,
           'h_dict':h_dict
           }

db.build(sys_dict,verbose=True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 26
#      12 h_dict.update(grid.dae['h_v_m_dict'])
#      14 sys_dict = {'name':'cigre_eu_lv_com',
#      15            'params_dict':params_dict,
#      16            'f_list':f_list,
#    (...)
#      23            'h_dict':h_dict
#      24            }
# ---> 26 db.build(sys_dict,verbose=True)
#
# AttributeError: module 'pydae.build_cffi' has no attribute 'build'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25828/521041098.py in <module>
# ----> 1 delta = np.deg2rad(30)
#       2 for item in grid.dae['xy_0_dict']:
#       3     ph = item.split('_')[2]
#       4     ir = item.split('_')[3]
#       5     if ph == 'a':
#
# NameError: name 'np' is not defined

# %%
delta = np.deg2rad(30)
for item in grid.dae['xy_0_dict']:
    ph = item.split('_')[2]
    ir = item.split('_')[3]
    if ph == 'a':
        v = 400.0/np.sqrt(3)*np.exp(1j*0.0+delta)
        if ir == 'r':
            grid.dae['xy_0_dict'][item] = v.real
        if ir == 'i':
            grid.dae['xy_0_dict'][item] = v.imag
    if ph == 'b':
        v = 400.0/np.sqrt(3)*np.exp(1j*(-2/3*np.pi+delta))
        if ir == 'r':
            grid.dae['xy_0_dict'][item] = v.real
        if ir == 'i':
            grid.dae['xy_0_dict'][item] = v.imag  
    if ph == 'c':
        v = 400.0/np.sqrt(3)*np.exp(1j*(-4/3*np.pi+delta))
        if ir == 'r':
            grid.dae['xy_0_dict'][item] = v.real
        if ir == 'i':
            grid.dae['xy_0_dict'][item] = v.imag 

data = json.dumps(grid.dae['xy_0_dict'], indent=4)
fobj = open("xy_0_dict.json","w")
fobj.write(data)
fobj.close()

# %%
grid.dae['xy_0_dict']
# Out:
# {'v_C01_a_r': 389.8481008958138,
#  'v_C01_a_i': 0.0,
#  'v_C01_b_r': 1.414100318299876e-14,
#  'v_C01_b_i': -230.94010767585033,
#  'v_C01_c_r': -200.00000000000006,
#  'v_C01_c_i': 115.4700538379251,
#  'v_C01_n_r': -4.778994804737777e-12,
#  'v_C01_n_i': 2.8491158660830726e-11,
#  'v_C12_a_r': 389.8481008958138,
#  'v_C12_a_i': 0.0,
#  'v_C12_b_r': 1.414100318299876e-14,
#  'v_C12_b_i': -230.94010767585033,
#  'v_C12_c_r': -200.00000000000006,
#  'v_C12_c_i': 115.4700538379251,
#  'v_C12_n_r': -3.96660648118238e-12,
#  'v_C12_n_i': 2.737234280526381e-11,
#  'v_C13_a_r': 389.8481008958138,
#  'v_C13_a_i': 0.0,
#  'v_C13_b_r': 1.414100318299876e-14,
#  'v_C13_b_i': -230.94010767585033,
#  'v_C13_c_r': -200.00000000000006,
#  'v_C13_c_i': 115.4700538379251,
#  'v_C13_n_r': -3.926588843223006e-12,
#  'v_C13_n_i': 2.731963267594935e-11,
#  'v_C14_a_r': 389.8481008958138,
#  'v_C14_a_i': 0.0,
#  'v_C14_b_r': 1.414100318299876e-14,
#  'v_C14_b_i': -230.94010767585033,
#  'v_C14_c_r': -200.00000000000006,
#  'v_C14_c_i': 115.4700538379251,
#  'v_C14_n_r': -4.099316666539259e-12,
#  'v_C14_n_i': 2.7451116108457393e-11,
#  'v_C17_a_r': 389.8481008958138,
#  'v_C17_a_i': 0.0,
#  'v_C17_b_r': 1.414100318299876e-14,
#  'v_C17_b_i': -230.94010767585033,
#  'v_C17_c_r': -200.00000000000006,
#  'v_C17_c_i': 115.4700538379251,
#  'v_C17_n_r': -4.292912456127972e-12,
#  'v_C17_n_i': 2.7082053100652236e-11,
#  'v_C18_a_r': 389.8481008958138,
#  'v_C18_a_i': 0.0,
#  'v_C18_b_r': 1.414100318299876e-14,
#  'v_C18_b_i': -230.94010767585033,
#  'v_C18_c_r': -200.00000000000006,
#  'v_C18_c_i': 115.4700538379251,
#  'v_C18_n_r': -4.066378408366837e-12,
#  'v_C18_n_i': 2.7022005823094878e-11,
#  'v_C19_a_r': 389.8481008958138,
#  'v_C19_a_i': 0.0,
#  'v_C19_b_r': 1.414100318299876e-14,
#  'v_C19_b_i': -230.94010767585033,
#  'v_C19_c_r': -200.00000000000006,
#  'v_C19_c_i': 115.4700538379251,
#  'v_C19_n_r': -4.093878896333918e-12,
#  'v_C19_n_i': 2.6644183112123746e-11,
#  'v_C20_a_r': 389.8481008958138,
#  'v_C20_a_i': 0.0,
#  'v_C20_b_r': 1.414100318299876e-14,
#  'v_C20_b_i': -230.94010767585033,
#  'v_C20_c_r': -200.00000000000006,
#  'v_C20_c_i': 115.4700538379251,
#  'v_C20_n_r': -4.061472636177294e-12,
#  'v_C20_n_i': 2.659515473397129e-11,
#  'v_C00_a_r': 389.8481008958138,
#  'v_C00_a_i': 0.0,
#  'v_C00_b_r': 1.414100318299876e-14,
#  'v_C00_b_i': -230.94010767585033,
#  'v_C00_c_r': -200.00000000000006,
#  'v_C00_c_i': 115.4700538379251,
#  'v_C02_a_r': 389.8481008958138,
#  'v_C02_a_i': 0.0,
#  'v_C02_b_r': 1.414100318299876e-14,
#  'v_C02_b_i': -230.94010767585033,
#  'v_C02_c_r': -200.00000000000006,
#  'v_C02_c_i': 115.4700538379251,
#  'v_C02_n_r': -4.59600222624853e-12,
#  'v_C02_n_i': 2.805760738389348e-11,
#  'v_C03_a_r': 389.8481008958138,
#  'v_C03_a_i': 0.0,
#  'v_C03_b_r': 1.414100318299876e-14,
#  'v_C03_b_i': -230.94010767585033,
#  'v_C03_c_r': -200.00000000000006,
#  'v_C03_c_i': 115.4700538379251,
#  'v_C03_n_r': -4.283665342114657e-12,
#  'v_C03_n_i': 2.7740339065464677e-11,
#  'v_C04_a_r': 389.8481008958138,
#  'v_C04_a_i': 0.0,
#  'v_C04_b_r': 1.414100318299876e-14,
#  'v_C04_b_i': -230.94010767585033,
#  'v_C04_c_r': -200.00000000000006,
#  'v_C04_c_i': 115.4700538379251,
#  'v_C04_n_r': -4.314141166591676e-12,
#  'v_C04_n_i': 2.7567248781299963e-11,
#  'v_C05_a_r': 389.8481008958138,
#  'v_C05_a_i': 0.0,
#  'v_C05_b_r': 1.414100318299876e-14,
#  'v_C05_b_i': -230.94010767585033,
#  'v_C05_c_r': -200.00000000000006,
#  'v_C05_c_i': 115.4700538379251,
#  'v_C05_n_r': -4.331637991125349e-12,
#  'v_C05_n_i': 2.730864005703675e-11,
#  'v_C06_a_r': 389.8481008958138,
#  'v_C06_a_i': 0.0,
#  'v_C06_b_r': 1.414100318299876e-14,
#  'v_C06_b_i': -230.94010767585033,
#  'v_C06_c_r': -200.00000000000006,
#  'v_C06_c_i': 115.4700538379251,
#  'v_C06_n_r': -4.185077631974514e-12,
#  'v_C06_n_i': 2.7053673985687088e-11,
#  'v_C07_a_r': 389.8481008958138,
#  'v_C07_a_i': 0.0,
#  'v_C07_b_r': 1.414100318299876e-14,
#  'v_C07_b_i': -230.94010767585033,
#  'v_C07_c_r': -200.00000000000006,
#  'v_C07_c_i': 115.4700538379251,
#  'v_C07_n_r': -4.10833155064946e-12,
#  'v_C07_n_i': 2.6848129132463057e-11,
#  'v_C08_a_r': 389.8481008958138,
#  'v_C08_a_i': 0.0,
#  'v_C08_b_r': 1.414100318299876e-14,
#  'v_C08_b_i': -230.94010767585033,
#  'v_C08_c_r': -200.00000000000006,
#  'v_C08_c_i': 115.4700538379251,
#  'v_C08_n_r': -4.1301096376537605e-12,
#  'v_C08_n_i': 2.6687360867906e-11,
#  'v_C09_a_r': 389.8481008958138,
#  'v_C09_a_i': 0.0,
#  'v_C09_b_r': 1.414100318299876e-14,
#  'v_C09_b_i': -230.94010767585033,
#  'v_C09_c_r': -200.00000000000006,
#  'v_C09_c_i': 115.4700538379251,
#  'v_C09_n_r': -4.0245343256372995e-12,
#  'v_C09_n_i': 2.6624870387253426e-11,
#  'v_C10_a_r': 389.8481008958138,
#  'v_C10_a_i': 0.0,
#  'v_C10_b_r': 1.414100318299876e-14,
#  'v_C10_b_i': -230.94010767585033,
#  'v_C10_c_r': -200.00000000000006,
#  'v_C10_c_i': 115.4700538379251,
#  'v_C10_n_r': -4.106642481887837e-12,
#  'v_C10_n_i': 2.749032385292582e-11,
#  'v_C11_a_r': 389.8481008958138,
#  'v_C11_a_i': 0.0,
#  'v_C11_b_r': 1.414100318299876e-14,
#  'v_C11_b_i': -230.94010767585033,
#  'v_C11_c_r': -200.00000000000006,
#  'v_C11_c_i': 115.4700538379251,
#  'v_C11_n_r': -3.980503428999959e-12,
#  'v_C11_n_i': 2.740725015579388e-11,
#  'v_C15_a_r': 389.8481008958138,
#  'v_C15_a_i': 0.0,
#  'v_C15_b_r': 1.414100318299876e-14,
#  'v_C15_b_i': -230.94010767585033,
#  'v_C15_c_r': -200.00000000000006,
#  'v_C15_c_i': 115.4700538379251,
#  'v_C15_n_r': -4.289025390409589e-12,
#  'v_C15_n_i': 2.712101866697209e-11,
#  'v_C16_a_r': 389.8481008958138,
#  'v_C16_a_i': 0.0,
#  'v_C16_b_r': 1.414100318299876e-14,
#  'v_C16_b_i': -230.94010767585033,
#  'v_C16_c_r': -200.00000000000006,
#  'v_C16_c_i': 115.4700538379251,
#  'v_C16_n_r': -4.175675229895396e-12,
#  'v_C16_n_i': 2.703206266611052e-11,
#  'i_load_C01_a_r': -1.3168781223048784e-11,
#  'i_load_C01_a_i': -5.697795028708508e-12,
#  'i_load_C01_b_r': 1.3156826265041098e-11,
#  'i_load_C01_b_i': -8.479368446497796e-12,
#  'i_load_C01_c_r': 2.575351570912929e-12,
#  'i_load_C01_c_i': 1.5631043449732922e-11,
#  'i_load_C01_n_r': -2.5633966129052428e-12,
#  'i_load_C01_n_i': -1.453879974526617e-12,
#  'i_load_C12_a_r': -2.1947968705081343e-12,
#  'i_load_C12_a_i': -9.49632504784749e-13,
#  'i_load_C12_b_r': 2.1928043775068486e-12,
#  'i_load_C12_b_i': -1.4132280744163047e-12,
#  'i_load_C12_c_r': 4.292252618188246e-13,
#  'i_load_C12_c_i': 2.6051739082888127e-12,
#  'i_load_C12_n_r': -4.272327688175389e-13,
#  'i_load_C12_n_i': -2.4231332908775887e-13,
#  'i_load_C13_a_r': -2.1947968705081343e-12,
#  'i_load_C13_a_i': -9.496325047847488e-13,
#  'i_load_C13_b_r': 2.192804377506849e-12,
#  'i_load_C13_b_i': -1.4132280744163045e-12,
#  'i_load_C13_c_r': 4.2922526181882446e-13,
#  'i_load_C13_c_i': 2.6051739082888135e-12,
#  'i_load_C13_n_r': -4.2723276881753914e-13,
#  'i_load_C13_n_i': -2.423133290877605e-13,
#  'i_load_C14_a_r': -2.7434960881351684e-12,
#  'i_load_C14_a_i': -1.187040630980936e-12,
#  'i_load_C14_b_r': 2.741005471883562e-12,
#  'i_load_C14_b_i': -1.7665350930203807e-12,
#  'i_load_C14_c_r': 5.365315772735293e-13,
#  'i_load_C14_c_i': 3.2564673853610162e-12,
#  'i_load_C14_n_r': -5.340409610219228e-13,
#  'i_load_C14_n_i': -3.028916613596995e-13,
#  'i_load_C17_a_r': -2.7434960881351745e-12,
#  'i_load_C17_a_i': -1.187040630980935e-12,
#  'i_load_C17_b_r': 2.7410054718835608e-12,
#  'i_load_C17_b_i': -1.7665350930203813e-12,
#  'i_load_C17_c_r': 5.365315772735194e-13,
#  'i_load_C17_c_i': 3.256467385361013e-12,
#  'i_load_C17_n_r': -5.340409610219057e-13,
#  'i_load_C17_n_i': -3.0289166135969667e-13,
#  'i_load_C18_a_r': -8.779187482032552e-13,
#  'i_load_C18_a_i': -3.7985300191389925e-13,
#  'i_load_C18_b_r': 8.771217510027392e-13,
#  'i_load_C18_b_i': -5.65291229766522e-13,
#  'i_load_C18_c_r': 1.716901047275241e-13,
#  'i_load_C18_c_i': 1.0420695633155245e-12,
#  'i_load_C18_n_r': -1.708931075270081e-13,
#  'i_load_C18_n_i': -9.692533163510327e-14,
#  'i_load_C19_a_r': -1.7558374964065132e-12,
#  'i_load_C19_a_i': -7.597060038277997e-13,
#  'i_load_C19_b_r': 1.754243502005478e-12,
#  'i_load_C19_b_i': -1.130582459533041e-12,
#  'i_load_C19_c_r': 3.433802094550537e-13,
#  'i_load_C19_c_i': 2.084139126631052e-12,
#  'i_load_C19_n_r': -3.417862150540185e-13,
#  'i_load_C19_n_i': -1.9385066327021098e-13,
#  'i_load_C20_a_r': -8.779187482032566e-13,
#  'i_load_C20_a_i': -3.7985300191389985e-13,
#  'i_load_C20_b_r': 8.77121751002739e-13,
#  'i_load_C20_b_i': -5.652912297665208e-13,
#  'i_load_C20_c_r': 1.7169010472752663e-13,
#  'i_load_C20_c_i': 1.0420695633155261e-12,
#  'i_load_C20_n_r': -1.70893107527009e-13,
#  'i_load_C20_n_i': -9.692533163510549e-14}

# %%
import pydgrid

# %%
grid = pydgrid.grid()
grid.read('cigre_eu_lv_com.json')
grid.pf()
grid.buses
# Out:
# [{'bus': 'C00',
#   'pos_x': 0,
#   'pos_y': 20,
#   'units': 'm',
#   'U_kV': 20.0,
#   'N_nodes': 3,
#   'v_an': 9406.14466972905,
#   'v_bn': 5342.487736902938,
#   'v_cn': 4897.532823174782,
#   'v_ng': 0.0,
#   'deg_an': 4.683252495528376,
#   'deg_bn': -1.5570016219167029,
#   'deg_cn': -10.255059580423513,
#   'deg_ng': 0.0,
#   'v_ab': 4136.280005162306,
#   'v_bc': 894.3331152950036,
#   'v_ca': 4841.625932933715,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': 0.0,
#   'q_b': -0.0,
#   'q_c': -0.0},
#  {'bus': 'C01',
#   'pos_x': 0,
#   'pos_y': 0,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.9062807138951,
#   'v_bn': 47.76164748848253,
#   'v_cn': 10.32686929721537,
#   'v_ng': 5.178110907553221e-16,
#   'deg_an': 19.798149901413684,
#   'deg_bn': -167.2459938617705,
#   'deg_cn': -125.64797754224392,
#   'deg_ng': -168.03564256913867,
#   'v_ab': 103.47333066383844,
#   'v_bc': 40.62174512906649,
#   'v_ca': 64.67718248865783,
#   'p_a': 2.09851578562799e-11,
#   'p_b': 2.0985157856279895e-11,
#   'p_c': 2.0985157856279892e-11,
#   'q_a': 7.808635339983814e-12,
#   'q_b': 7.808635339983814e-12,
#   'q_c': 7.808635339983803e-12},
#  {'bus': 'C02',
#   'pos_x': 0,
#   'pos_y': -35,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389507,
#   'v_bn': 47.761647488482566,
#   'v_cn': 10.326869297215426,
#   'v_ng': 4.412296211636579e-14,
#   'deg_an': 19.798149901413606,
#   'deg_bn': -167.24599386177047,
#   'deg_cn': -125.64797754224375,
#   'deg_ng': -51.192540772287174,
#   'v_ab': 103.47333066383847,
#   'v_bc': 40.62174512906652,
#   'v_ca': 64.67718248865783,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C03',
#   'pos_x': 0,
#   'pos_y': -70,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389504,
#   'v_bn': 47.761647488482616,
#   'v_cn': 10.32686929721549,
#   'v_ng': 7.388874306484865e-14,
#   'deg_an': 19.798149901413534,
#   'deg_bn': -167.24599386177047,
#   'deg_cn': -125.6479775422436,
#   'deg_ng': -39.26695883311821,
#   'v_ab': 103.47333066383848,
#   'v_bc': 40.62174512906654,
#   'v_ca': 64.67718248865783,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C04',
#   'pos_x': 0,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389503,
#   'v_bn': 47.76164748848262,
#   'v_cn': 10.326869297215518,
#   'v_ng': 1.0515507612045678e-13,
#   'deg_an': 19.798149901413503,
#   'deg_bn': -167.24599386177047,
#   'deg_cn': -125.64797754224347,
#   'deg_ng': -42.29851594933286,
#   'v_ab': 103.4733306638385,
#   'v_bc': 40.62174512906655,
#   'v_ca': 64.67718248865785,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C05',
#   'pos_x': 0,
#   'pos_y': -140,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.906280713895,
#   'v_bn': 47.761647488482645,
#   'v_cn': 10.326869297215543,
#   'v_ng': 1.31138139484569e-13,
#   'deg_an': 19.79814990141349,
#   'deg_bn': -167.24599386177047,
#   'deg_cn': -125.64797754224337,
#   'deg_ng': -42.45983001958275,
#   'v_ab': 103.4733306638385,
#   'v_bc': 40.62174512906657,
#   'v_ca': 64.67718248865782,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C06',
#   'pos_x': 0,
#   'pos_y': -175,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389498,
#   'v_bn': 47.76164748848265,
#   'v_cn': 10.326869297215557,
#   'v_ng': 1.4784696437278008e-13,
#   'deg_an': 19.798149901413474,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224328,
#   'deg_ng': -40.615355518503,
#   'v_ab': 103.47333066383847,
#   'v_bc': 40.621745129066575,
#   'v_ca': 64.6771824886578,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C07',
#   'pos_x': 0,
#   'pos_y': -210,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.906280713894965,
#   'v_bn': 47.761647488482666,
#   'v_cn': 10.326869297215552,
#   'v_ng': 1.6420162556154207e-13,
#   'deg_an': 19.798149901413463,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224321,
#   'deg_ng': -38.773995385028584,
#   'v_ab': 103.47333066383845,
#   'v_bc': 40.6217451290666,
#   'v_ca': 64.67718248865778,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C08',
#   'pos_x': 0,
#   'pos_y': -245,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389495,
#   'v_bn': 47.76164748848265,
#   'v_cn': 10.326869297215552,
#   'v_ng': 1.8247650106426905e-13,
#   'deg_an': 19.79814990141345,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224315,
#   'deg_ng': -38.18575577361021,
#   'v_ab': 103.47333066383842,
#   'v_bc': 40.621745129066596,
#   'v_ca': 64.67718248865776,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C09',
#   'pos_x': 0,
#   'pos_y': -280,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389493,
#   'v_bn': 47.76164748848265,
#   'v_cn': 10.326869297215552,
#   'v_ng': 1.780292497802229e-13,
#   'deg_an': 19.79814990141344,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224318,
#   'deg_ng': -36.7623265909356,
#   'v_ab': 103.47333066383842,
#   'v_bc': 40.62174512906659,
#   'v_ca': 64.67718248865775,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C10',
#   'pos_x': 0,
#   'pos_y': -315,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389497,
#   'v_bn': 47.761647488482666,
#   'v_cn': 10.326869297215584,
#   'v_ng': 9.848042749459908e-14,
#   'deg_an': 19.798149901413503,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224372,
#   'deg_ng': -16.830101992340843,
#   'v_ab': 103.47333066383847,
#   'v_bc': 40.62174512906652,
#   'v_ca': 64.67718248865786,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C11',
#   'pos_x': -30,
#   'pos_y': -70,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.906280713894965,
#   'v_bn': 47.761647488482694,
#   'v_cn': 10.326869297215643,
#   'v_ng': 1.1483445202994885e-13,
#   'deg_an': 19.79814990141349,
#   'deg_bn': -167.2459938617704,
#   'deg_cn': -125.64797754224375,
#   'deg_ng': -4.290487752700511,
#   'v_ab': 103.4733306638385,
#   'v_bc': 40.62174512906649,
#   'v_ca': 64.6771824886579,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C12',
#   'pos_x': 35,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389494,
#   'v_bn': 47.76164748848273,
#   'v_cn': 10.326869297215685,
#   'v_ng': 1.3057918249881032e-13,
#   'deg_an': 19.798149901413485,
#   'deg_bn': -167.2459938617704,
#   'deg_cn': -125.6479775422438,
#   'deg_ng': 1.9717350366982713,
#   'v_ab': 103.4733306638385,
#   'v_bc': 40.6217451290665,
#   'v_ca': 64.67718248865792,
#   'p_a': 3.4975263093799832e-12,
#   'p_b': 3.4975263093799836e-12,
#   'p_c': 3.497526309379981e-12,
#   'q_a': 1.3014392233306353e-12,
#   'q_b': 1.3014392233306353e-12,
#   'q_c': 1.3014392233306345e-12},
#  {'bus': 'C13',
#   'pos_x': 70,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389495,
#   'v_bn': 47.76164748848273,
#   'v_cn': 10.326869297215687,
#   'v_ng': 1.305387777305796e-13,
#   'deg_an': 19.798149901413478,
#   'deg_bn': -167.2459938617704,
#   'deg_cn': -125.6479775422438,
#   'deg_ng': 2.1951439837745035,
#   'v_ab': 103.47333066383851,
#   'v_bc': 40.6217451290665,
#   'v_ca': 64.67718248865793,
#   'p_a': 3.497526309379984e-12,
#   'p_b': 3.4975263093799836e-12,
#   'p_c': 3.497526309379982e-12,
#   'q_a': 1.3014392233306355e-12,
#   'q_b': 1.3014392233306353e-12,
#   'q_c': 1.3014392233306343e-12},
#  {'bus': 'C14',
#   'pos_x': 105,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389496,
#   'v_bn': 47.76164748848272,
#   'v_cn': 10.326869297215636,
#   'v_ng': 1.1510455190219329e-13,
#   'deg_an': 19.798149901413492,
#   'deg_bn': -167.24599386177042,
#   'deg_cn': -125.64797754224377,
#   'deg_ng': -5.861423122236739,
#   'v_ab': 103.47333066383851,
#   'v_bc': 40.62174512906652,
#   'v_ca': 64.6771824886579,
#   'p_a': 4.371907886724981e-12,
#   'p_b': 4.371907886724979e-12,
#   'p_c': 4.371907886724977e-12,
#   'q_a': 1.6267990291632937e-12,
#   'q_b': 1.6267990291632943e-12,
#   'q_c': 1.6267990291632908e-12},
#  {'bus': 'C15',
#   'pos_x': 105,
#   'pos_y': -140,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389496,
#   'v_bn': 47.761647488482666,
#   'v_cn': 10.32686929721563,
#   'v_ng': 1.39422429575382e-13,
#   'deg_an': 19.798149901413467,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224337,
#   'deg_ng': -28.878407346023945,
#   'v_ab': 103.47333066383845,
#   'v_bc': 40.62174512906654,
#   'v_ca': 64.67718248865785,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C16',
#   'pos_x': -35,
#   'pos_y': -175,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389493,
#   'v_bn': 47.7616474884827,
#   'v_cn': 10.326869297215662,
#   'v_ng': 1.445449539678576e-13,
#   'deg_an': 19.798149901413446,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224331,
#   'deg_ng': -21.751848121296806,
#   'v_ab': 103.47333066383847,
#   'v_bc': 40.621745129066554,
#   'v_ca': 64.67718248865785,
#   'p_a': 0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C17',
#   'pos_x': 30,
#   'pos_y': -280,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389491,
#   'v_bn': 47.76164748848273,
#   'v_cn': 10.32686929721571,
#   'v_ng': 1.6005545605776255e-13,
#   'deg_an': 19.798149901413435,
#   'deg_bn': -167.24599386177042,
#   'deg_cn': -125.64797754224334,
#   'deg_ng': -12.668910338751672,
#   'v_ab': 103.47333066383847,
#   'v_bc': 40.62174512906655,
#   'v_ca': 64.67718248865786,
#   'p_a': 4.371907886724981e-12,
#   'p_b': 4.3719078867249795e-12,
#   'p_c': 4.371907886724979e-12,
#   'q_a': 1.6267990291632937e-12,
#   'q_b': 1.6267990291632939e-12,
#   'q_c': 1.6267990291632939e-12},
#  {'bus': 'C18',
#   'pos_x': -30,
#   'pos_y': -315,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.906280713894944,
#   'v_bn': 47.76164748848268,
#   'v_cn': 10.326869297215637,
#   'v_ng': 1.3933350964474181e-13,
#   'deg_an': 19.79814990141346,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224337,
#   'deg_ng': -27.058196938908903,
#   'v_ab': 103.47333066383844,
#   'v_bc': 40.62174512906655,
#   'v_ca': 64.67718248865783,
#   'p_a': 1.3990105237519935e-12,
#   'p_b': 1.3990105237519933e-12,
#   'p_c': 1.3990105237519933e-12,
#   'q_a': 5.205756893322542e-13,
#   'q_b': 5.205756893322541e-13,
#   'q_c': 5.205756893322541e-13},
#  {'bus': 'C19',
#   'pos_x': -35,
#   'pos_y': -175,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389492,
#   'v_bn': 47.76164748848268,
#   'v_cn': 10.326869297215604,
#   'v_ng': 1.9065074158569225e-13,
#   'deg_an': 19.798149901413435,
#   'deg_bn': -167.24599386177042,
#   'deg_cn': -125.64797754224315,
#   'deg_ng': -30.92975964434059,
#   'v_ab': 103.47333066383844,
#   'v_bc': 40.621745129066596,
#   'v_ca': 64.67718248865778,
#   'p_a': 2.7980210475039874e-12,
#   'p_b': 2.798021047503987e-12,
#   'p_c': 2.7980210475039858e-12,
#   'q_a': 1.0411513786645085e-12,
#   'q_b': 1.0411513786645081e-12,
#   'q_c': 1.041151378664507e-12},
#  {'bus': 'C20',
#   'pos_x': 30,
#   'pos_y': -280,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 55.90628071389492,
#   'v_bn': 47.761647488482666,
#   'v_cn': 10.326869297215573,
#   'v_ng': 1.835300106215456e-13,
#   'deg_an': 19.798149901413442,
#   'deg_bn': -167.24599386177044,
#   'deg_cn': -125.64797754224318,
#   'deg_ng': -34.257740714827,
#   'v_ab': 103.47333066383842,
#   'v_bc': 40.621745129066596,
#   'v_ca': 64.67718248865775,
#   'p_a': 1.3990105237519937e-12,
#   'p_b': 1.3990105237519935e-12,
#   'p_c': 1.3990105237519929e-12,
#   'q_a': 5.205756893322542e-13,
#   'q_b': 5.205756893322543e-13,
#   'q_c': 5.205756893322534e-13}]

# %%
# Out:
# [{'bus': 'C00',
#   'pos_x': 0,
#   'pos_y': 20,
#   'units': 'm',
#   'U_kV': 20.0,
#   'N_nodes': 3,
#   'v_an': 18975.157251962235,
#   'v_bn': 11326.53044728479,
#   'v_cn': 19061.51142817643,
#   'v_ng': 0.0,
#   'deg_an': -97.35887842404262,
#   'deg_bn': -141.30330811751048,
#   'deg_cn': -175.1897762042719,
#   'deg_ng': 0.0,
#   'v_ab': 13373.575729040731,
#   'v_bc': 11540.105064252955,
#   'v_ca': 23893.698014641428,
#   'p_a': -0.0,
#   'p_b': -0.0,
#   'p_c': -0.0,
#   'q_a': 0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C01',
#   'pos_x': 0,
#   'pos_y': 0,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.9006596137771,
#   'v_bn': 154.4247509437904,
#   'v_cn': 133.25365530646008,
#   'v_ng': 6.938763282472471e-13,
#   'deg_an': -46.11320934782988,
#   'deg_bn': 118.63779939765645,
#   'deg_cn': 151.63300943164225,
#   'deg_ng': 101.21279067180744,
#   'v_ab': 426.82527889782386,
#   'v_bc': 84.17782806565988,
#   'v_ca': 404.8560454675818,
#   'p_a': 5.560941244439301e-10,
#   'p_b': 5.560941244439301e-10,
#   'p_c': 5.5609412444393e-10,
#   'q_a': -3.047180252088705e-11,
#   'q_b': -3.047180252088713e-11,
#   'q_c': -3.0471802520887076e-11},
#  {'bus': 'C02',
#   'pos_x': 0,
#   'pos_y': -35,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.9006596137768,
#   'v_bn': 154.42475094379054,
#   'v_cn': 133.25365530646022,
#   'v_ng': 5.421723694053652e-13,
#   'deg_an': -46.1132093478299,
#   'deg_bn': 118.63779939765644,
#   'deg_cn': 151.63300943164222,
#   'deg_ng': 98.21605592753704,
#   'v_ab': 426.82527889782364,
#   'v_bc': 84.17782806566001,
#   'v_ca': 404.8560454675816,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C03',
#   'pos_x': 0,
#   'pos_y': -70,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.9006596137765,
#   'v_bn': 154.42475094379063,
#   'v_cn': 133.25365530646036,
#   'v_ng': 4.2820872319308744e-13,
#   'deg_an': -46.11320934782991,
#   'deg_bn': 118.63779939765638,
#   'deg_cn': 151.63300943164222,
#   'deg_ng': 91.2655158550685,
#   'v_ab': 426.8252788978235,
#   'v_bc': 84.17782806566007,
#   'v_ca': 404.85604546758145,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C04',
#   'pos_x': 0,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377627,
#   'v_bn': 154.4247509437906,
#   'v_cn': 133.25365530646047,
#   'v_ng': 3.5325072202036553e-13,
#   'deg_an': -46.113209347829894,
#   'deg_bn': 118.63779939765641,
#   'deg_cn': 151.63300943164222,
#   'deg_ng': 94.3770202258006,
#   'v_ab': 426.82527889782324,
#   'v_bc': 84.17782806566,
#   'v_ca': 404.85604546758145,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C05',
#   'pos_x': 0,
#   'pos_y': -140,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377616,
#   'v_bn': 154.42475094379068,
#   'v_cn': 133.25365530646056,
#   'v_ng': 1.7687656359073223e-13,
#   'deg_an': -46.11320934782991,
#   'deg_bn': 118.63779939765644,
#   'deg_cn': 151.6330094316422,
#   'deg_ng': 92.48827341954438,
#   'v_ab': 426.8252788978232,
#   'v_bc': 84.17782806565995,
#   'v_ca': 404.85604546758134,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C06',
#   'pos_x': 0,
#   'pos_y': -175,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377604,
#   'v_bn': 154.42475094379068,
#   'v_cn': 133.2536553064606,
#   'v_ng': 1.0440238507980265e-13,
#   'deg_an': -46.113209347829915,
#   'deg_bn': 118.63779939765645,
#   'deg_cn': 151.6330094316422,
#   'deg_ng': 110.2570071678944,
#   'v_ab': 426.8252788978232,
#   'v_bc': 84.17782806565987,
#   'v_ca': 404.85604546758134,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C07',
#   'pos_x': 0,
#   'pos_y': -210,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377604,
#   'v_bn': 154.42475094379068,
#   'v_cn': 133.25365530646056,
#   'v_ng': 2.6628881329039625e-14,
#   'deg_an': -46.11320934782993,
#   'deg_bn': 118.63779939765645,
#   'deg_cn': 151.63300943164222,
#   'deg_ng': 127.11685148217815,
#   'v_ab': 426.8252788978231,
#   'v_bc': 84.17782806565988,
#   'v_ca': 404.8560454675813,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C08',
#   'pos_x': 0,
#   'pos_y': -245,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377593,
#   'v_bn': 154.4247509437907,
#   'v_cn': 133.25365530646056,
#   'v_ng': 6.340818455320197e-14,
#   'deg_an': -46.11320934782995,
#   'deg_bn': 118.63779939765648,
#   'deg_cn': 151.63300943164222,
#   'deg_ng': -117.28306990066574,
#   'v_ab': 426.825278897823,
#   'v_bc': 84.17782806565987,
#   'v_ca': 404.85604546758105,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C09',
#   'pos_x': 0,
#   'pos_y': -280,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377593,
#   'v_bn': 154.42475094379068,
#   'v_cn': 133.25365530646056,
#   'v_ng': 3.6984721964882215e-14,
#   'deg_an': -46.11320934782994,
#   'deg_bn': 118.63779939765651,
#   'deg_cn': 151.63300943164222,
#   'deg_ng': -116.48062516912853,
#   'v_ab': 426.825278897823,
#   'v_bc': 84.17782806565987,
#   'v_ca': 404.85604546758105,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C10',
#   'pos_x': 0,
#   'pos_y': -315,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.9006596137761,
#   'v_bn': 154.42475094379074,
#   'v_cn': 133.25365530646053,
#   'v_ng': 1.9419274202995637e-13,
#   'deg_an': -46.11320934782991,
#   'deg_bn': 118.63779939765638,
#   'deg_cn': 151.6330094316422,
#   'deg_ng': 88.70672489545504,
#   'v_ab': 426.82527889782324,
#   'v_bc': 84.1778280656601,
#   'v_ca': 404.8560454675813,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C11',
#   'pos_x': -30,
#   'pos_y': -70,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.900659613776,
#   'v_bn': 154.42475094379083,
#   'v_cn': 133.2536553064606,
#   'v_ng': 7.082940761468333e-14,
#   'deg_an': -46.11320934782989,
#   'deg_bn': 118.63779939765638,
#   'deg_cn': 151.63300943164217,
#   'deg_ng': 70.61074924382064,
#   'v_ab': 426.8252788978231,
#   'v_bc': 84.1778280656601,
#   'v_ca': 404.8560454675813,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C12',
#   'pos_x': 35,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377593,
#   'v_bn': 154.4247509437909,
#   'v_cn': 133.2536553064607,
#   'v_ng': 4.8928957203196797e-14,
#   'deg_an': -46.11320934782989,
#   'deg_bn': 118.63779939765638,
#   'deg_cn': 151.63300943164217,
#   'deg_ng': 21.291349222620372,
#   'v_ab': 426.82527889782324,
#   'v_bc': 84.17782806566015,
#   'v_ca': 404.85604546758134,
#   'p_a': 9.268235407398837e-11,
#   'p_b': 9.268235407398834e-11,
#   'p_c': 9.268235407398834e-11,
#   'q_a': -5.078633753481188e-12,
#   'q_b': -5.0786337534811814e-12,
#   'q_c': -5.0786337534811814e-12},
#  {'bus': 'C13',
#   'pos_x': 70,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377593,
#   'v_bn': 154.42475094379094,
#   'v_cn': 133.2536553064607,
#   'v_ng': 3.660099054369786e-14,
#   'deg_an': -46.11320934782988,
#   'deg_bn': 118.63779939765638,
#   'deg_cn': 151.63300943164217,
#   'deg_ng': 14.98440357097414,
#   'v_ab': 426.82527889782324,
#   'v_bc': 84.17782806566017,
#   'v_ca': 404.85604546758134,
#   'p_a': 9.268235407398834e-11,
#   'p_b': 9.268235407398834e-11,
#   'p_c': 9.268235407398833e-11,
#   'q_a': -5.078633753481175e-12,
#   'q_b': -5.078633753481194e-12,
#   'q_c': -5.078633753481188e-12},
#  {'bus': 'C14',
#   'pos_x': 105,
#   'pos_y': -105,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377604,
#   'v_bn': 154.42475094379097,
#   'v_cn': 133.25365530646067,
#   'v_ng': 1.0497876023978902e-13,
#   'deg_an': -46.113209347829894,
#   'deg_bn': 118.63779939765638,
#   'deg_cn': 151.63300943164217,
#   'deg_ng': 60.062819682073936,
#   'v_ab': 426.82527889782335,
#   'v_bc': 84.17782806566012,
#   'v_ca': 404.8560454675814,
#   'p_a': 1.1585294259248544e-10,
#   'p_b': 1.1585294259248542e-10,
#   'p_c': 1.1585294259248543e-10,
#   'q_a': -6.348292191851482e-12,
#   'q_b': -6.3482921918515075e-12,
#   'q_c': -6.3482921918514945e-12},
#  {'bus': 'C15',
#   'pos_x': 105,
#   'pos_y': -140,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.900659613776,
#   'v_bn': 154.42475094379074,
#   'v_cn': 133.25365530646076,
#   'v_ng': 6.292018199880822e-14,
#   'deg_an': -46.1132093478299,
#   'deg_bn': 118.63779939765644,
#   'deg_cn': 151.6330094316422,
#   'deg_ng': 87.54835946772882,
#   'v_ab': 426.8252788978231,
#   'v_bc': 84.17782806565998,
#   'v_ca': 404.8560454675814,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C16',
#   'pos_x': -35,
#   'pos_y': -175,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.9006596137759,
#   'v_bn': 154.42475094379083,
#   'v_cn': 133.25365530646073,
#   'v_ng': 3.7303551026227897e-14,
#   'deg_an': -46.1132093478299,
#   'deg_bn': 118.63779939765644,
#   'deg_cn': 151.6330094316422,
#   'deg_ng': 88.2970339882576,
#   'v_ab': 426.825278897823,
#   'v_bc': 84.17782806566005,
#   'v_ca': 404.85604546758117,
#   'p_a': 0.0,
#   'p_b': 0.0,
#   'p_c': 0.0,
#   'q_a': -0.0,
#   'q_b': 0.0,
#   'q_c': 0.0},
#  {'bus': 'C17',
#   'pos_x': 30,
#   'pos_y': -280,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.9006596137759,
#   'v_bn': 154.4247509437908,
#   'v_cn': 133.25365530646081,
#   'v_ng': 4.186468705992953e-14,
#   'deg_an': -46.11320934782991,
#   'deg_bn': 118.63779939765644,
#   'deg_cn': 151.6330094316422,
#   'deg_ng': 42.101950906063706,
#   'v_ab': 426.825278897823,
#   'v_bc': 84.17782806566,
#   'v_ca': 404.8560454675813,
#   'p_a': 1.1585294259248544e-10,
#   'p_b': 1.1585294259248543e-10,
#   'p_c': 1.1585294259248546e-10,
#   'q_a': -6.348292191851501e-12,
#   'q_b': -6.348292191851469e-12,
#   'q_c': -6.348292191851482e-12},
#  {'bus': 'C18',
#   'pos_x': -30,
#   'pos_y': -315,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.9006596137759,
#   'v_bn': 154.42475094379085,
#   'v_cn': 133.25365530646067,
#   'v_ng': 3.41556261374705e-14,
#   'deg_an': -46.11320934782991,
#   'deg_bn': 118.63779939765644,
#   'deg_cn': 151.6330094316422,
#   'deg_ng': 35.050208240659884,
#   'v_ab': 426.8252788978231,
#   'v_bc': 84.17782806566007,
#   'v_ca': 404.85604546758117,
#   'p_a': 3.707294162959534e-11,
#   'p_b': 3.7072941629595326e-11,
#   'p_c': 3.707294162959533e-11,
#   'q_a': -2.0314535013924816e-12,
#   'q_b': -2.0314535013924687e-12,
#   'q_c': -2.031453501392472e-12},
#  {'bus': 'C19',
#   'pos_x': -35,
#   'pos_y': -175,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377593,
#   'v_bn': 154.42475094379074,
#   'v_cn': 133.25365530646062,
#   'v_ng': 5.639327011305592e-14,
#   'deg_an': -46.11320934782996,
#   'deg_bn': 118.63779939765651,
#   'deg_cn': 151.63300943164225,
#   'deg_ng': -82.32957878868318,
#   'v_ab': 426.8252788978231,
#   'v_bc': 84.17782806565992,
#   'v_ca': 404.8560454675811,
#   'p_a': 7.414588325919068e-11,
#   'p_b': 7.414588325919067e-11,
#   'p_c': 7.414588325919067e-11,
#   'q_a': -4.062907002784957e-12,
#   'q_b': -4.062907002784937e-12,
#   'q_c': -4.062907002784944e-12},
#  {'bus': 'C20',
#   'pos_x': 30,
#   'pos_y': -280,
#   'units': 'm',
#   'U_kV': 0.4,
#   'N_nodes': 4,
#   'v_an': 275.90065961377593,
#   'v_bn': 154.42475094379074,
#   'v_cn': 133.25365530646064,
#   'v_ng': 3.405171449287963e-14,
#   'deg_an': -46.11320934782996,
#   'deg_bn': 118.63779939765651,
#   'deg_cn': 151.63300943164222,
#   'deg_ng': -98.77746717832731,
#   'v_ab': 426.8252788978231,
#   'v_bc': 84.17782806565991,
#   'v_ca': 404.8560454675811,
#   'p_a': 3.7072941629595346e-11,
#   'p_b': 3.707294162959534e-11,
#   'p_c': 3.7072941629595346e-11,
#   'q_a': -2.031453501392475e-12,
#   'q_b': -2.0314535013924687e-12,
#   'q_c': -2.031453501392464e-12}]
